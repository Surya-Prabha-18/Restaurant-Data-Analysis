# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data.csv')

# %%
groupedDate = df.groupby('Date')['Final Total'].mean().sort_values(ascending = False)
groupedDate.head(1)
# Out:
# Date
# 2023-07-19    319.837857
# Name: Final Total, dtype: float64

# %%
groupedBill  = df.groupby('Invoice No.').count()
# groupedBill.count()

# df['Invoice No.'].nunique()

# %%
# df.head()

# %%
date =  df[(df['Date'] <= '2023-09-30') & ('2023-09-01'>= df['Date'])].groupby('Item Name')['Final Total'].sum().sort_values(ascending = False)
date
# Out:
# Item Name
# Chicken Biriyani With Raitha And Gravy    101540.88
# Chicken Fried Rice                         47199.60
# Butter Naan                                23098.96
# Chicken Noodles                            18231.36
# Chicken Lolly Pop                          17546.06
#                                             ...
# Black Current Scoop                           93.56
# Tomato Soup                                   84.00
# Dhai Poori                                    52.50
# Full Boil                                     42.00
# Soft Drinks Tin                               42.00
# Name: Final Total, Length: 244, dtype: float64

# %%
lessSold = df[(df['Date'] <= '2023-07-31') & (df['Date'] >= '2023-07-01')].groupby('Category')['Qty.'].sum().sort_values(ascending = True)

lessSold.head(3)
# Out:
# Category
# NON VEG STARTERS FISH    49.0
# NON VEG STARTERS EGG     53.0
# Veg Soup                 53.0
# Name: Qty., dtype: float64

# %%
salesCategory = df.groupby('Category')['Final Total'].sum()
# plt.pie(df['Category'])
plt.pie(salesCategory, labels = salesCategory.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c098fc6300>,
# ...
#  [Text(1.090144250430971, 0.14692009138404527, 'Deserts & Mocktails'),
#   Text(0.9238335473339688, 0.5971026518282562, 'Indian Breads'),
#   Text(-0.320554884663158, 1.0522568915994752, 'NON VEG BRIYANI & RICE'),
#   Text(-1.0764596250718697, -0.22635077996359948, 'NON VEG STARTERS CHICKEN'),
#   Text(-0.8257766498242136, -0.7267000238097548, 'NON VEG STARTERS EGG'),
#   Text(-0.7357963526341846, -0.8176819231524143, 'NON VEG STARTERS FISH'),
#   Text(-0.6521406171672405, -0.8858400619980623, 'NON VEG STARTERS MUTTON'),
#   Text(-0.34055632582973516, -1.045954773848923, 'Non Veg Gravy'),
#   Text(0.08406323505305217, -1.096783193029696, 'Non Veg Soup'),
#   Text(0.306999331264075, -1.0562913474053504, 'Non Veg Tandoor'),
#   Text(0.4634949385981277, -0.9975833007292765, 'Non Veg combos'),
#   Text(0.704253481924187, -0.8450012030746815, 'VEG BIRYANI & RICE'),
#   Text(0.9693852532360601, -0.5198963654503268, 'Veg Gravy'),
# ...

# %%
salesCategory = df.groupby('Category')['Qty.'].sum()
# plt.pie(df['Category'])
plt.pie(salesCategory, labels = salesCategory.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c099019e20>,
# ...
#  [Text(1.010517942189517, 0.43457276549855733, 'Deserts & Mocktails'),
#   Text(0.06361304039231423, 1.0981590873329994, 'Indian Breads'),
#   Text(-1.0778150490628218, 0.21980609639795598, 'NON VEG BRIYANI & RICE'),
#   Text(-0.7198701277657378, -0.8317373378360146, 'NON VEG STARTERS CHICKEN'),
#   Text(-0.3665908422130008, -1.037116750614685, 'NON VEG STARTERS EGG'),
#   Text(-0.2622757131817036, -1.068274988135091, 'NON VEG STARTERS FISH'),
#   Text(-0.20056999151221372, -1.0815598358411755, 'NON VEG STARTERS MUTTON'),
#   Text(0.039013327676177205, -1.0993079460568052, 'Non Veg Gravy'),
#   Text(0.3741026801023396, -1.0344308506324853, 'Non Veg Soup'),
#   Text(0.5330933077818896, -0.9621910024512617, 'Non Veg Tandoor'),
#   Text(0.6040250415914706, -0.919322440240867, 'Non Veg combos'),
#   Text(0.789681741330557, -0.7657693826532499, 'VEG BIRYANI & RICE'),
#   Text(0.9911087011146267, -0.4771829235994073, 'Veg Gravy'),
# ...
